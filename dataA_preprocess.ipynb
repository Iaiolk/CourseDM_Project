# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 城镇化率处理
urbanization = pd.read_excel('data/dataA/城镇化率.xlsx')
# 查看数据前5行
print("the first 5 rows of the data are:")
print(urbanization.head())
# 查看数据的基本信息
print("\nthe basic information of the data is:")
print(urbanization.info())
groups = urbanization.groupby('城市名称',sort=True)
print("\nthe number of cities is:")
print(len(groups))
for name,group in groups:
  group = group.sort_values(by='年份')
  # 绘制城镇化率变化曲线
  plt.plot(group['年份'],group['urbanizationRate'],label=name)
plt.legend()
plt.show()
# Out:
# the first 5 rows of the data are:
#     城市名称    年份  urbanizationRate
# 0  city1  2007                48
# 1  city1  2008                49
# 2  city1  2009                50
# 3  city1  2010                51
# 4  city1  2011                53
#
# the basic information of the data is:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   城市名称              675 non-null    object
#  1   年份                675 non-null    int64
#  2   urbanizationRate  675 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 15.9+ KB
# None
#
# the number of cities is:
# 40
